// %% [markdown]
// --- Day 1: Report Repair ---
//
// After saving Christmas five years in a row, you've decided to take a vacation at a nice resort on a tropical island. Surely, Christmas will go on without you.
//
// The tropical island has its own currency and is entirely cash-only. The gold coins used there have a little picture of a starfish; the locals just call them stars. None of the currency exchanges seem to have heard of them, but somehow, you'll need to find fifty of these coins by the time you arrive so you can pay the deposit on your room.
//
// To save your vacation, you need to get all fifty stars by December 25th.
//
// Collect stars by solving puzzles. Two puzzles will be made available on each day in the Advent calendar; the second puzzle is unlocked when you complete the first. Each puzzle grants one star. Good luck!
//
// Before you leave, the Elves in accounting just need you to fix your expense report (your puzzle input); apparently, something isn't quite adding up.
//
// Specifically, they need you to find the two entries that sum to 2020 and then multiply those two numbers together.
//
// For example, suppose your expense report contained the following:
//
// 1721
// 979
// 366
// 299
// 675
// 1456
//
// In this list, the two entries that sum to 2020 are 1721 and 299. Multiplying them together produces 1721 * 299 = 514579, so the correct answer is 514579.
//
// Of course, your expense report is much larger. Find the two entries that sum to 2020; what do you get if you multiply them together?

// %%
public string input = @"
1895
1504
1660
1775
1743
1607
1267
1133
292
1646
1285
1808
1512
1839
1869
1578
1318
1385
1829
1800
1491
1600
1290
1856
1781
1881
1953
2008
1681
1472
1846
2010
1619
1584
1849
1876
1744
1980
1421
911
1308
1762
1398
1470
1974
1902
1985
2001
1926
1374
1678
1523
1894
1597
1778
1940
1362
1613
1629
1473
1633
1867
1838
1931
1850
1776
1689
1311
1947
1988
1779
1381
1683
1677
1675
1587
767
1401
1412
1544
1484
618
1755
1073
1970
1735
1770
1623
1665
1783
1400
1892
1921
1506
1978
1731
1739
1515
1354
1264
1394
1763
1569
1453
1539
2006
1586
1855
1609
1729
1624
506
1668
1803
1486
1767
1720
1753
1994
1718
1922
1314
1250
1516
1546
1625
1708
1286
1993
1785
491
1705
1924
1752
1888
1651
1604
1750
1547
1481
1704
1851
904
1920
1939
1277
1870
1934
1617
1833
1797
1817
1967
1935
1914
1621
1468
1859
1552
1640
1709
1121
1973
1343
1266
1806
1360
1299
1990
1356
1631
1555
1811
1323
1794
1550
1448
1848
1826
1723
1891
1302
1655
947
1580
1908
1641
1816
1701
1871
1588
1843
1643
1893
1866
1628
1417
1795
1995
1937
";

// %%
public int? GetResultNumberOne(string input)
{
    string[] inputStrings = input.Split();
    string[] comparer = input.Split();
    
    foreach(string item in inputStrings)
    {
        foreach(string compar in comparer)
        {
            if(int.TryParse(item, out int itemParsed) && int.TryParse(compar, out int comparParsed))
            {
                int result = itemParsed + comparParsed;
                if(result.Equals(2020))
                {
                    return itemParsed * comparParsed;
                }
            }
        }
    }
    return null;
}

public void ShowResult(string input)
{
    int? result = GetResultNumberOne(input);

    if(result.HasValue)
    {
        Console.WriteLine(result.Value);
    }
}

ShowResult(input);
// Out:
// 1016131

// %%
public int? GetResultNumberOneB(string input)
{
    string[] inputStrings = input.Split();
    string[] comparer = input.Split();
    string[] comparerPartTwo = input.Split();
    
    foreach(string item in inputStrings)
    {
        foreach(string compar in comparer)
        {
            foreach(string comparB in comparerPartTwo)
            {
                if(int.TryParse(item, out int itemParsed) && int.TryParse(compar, out int comparParsed) && int.TryParse(comparB, out int comparParsedB))
                {
                    int result = itemParsed + comparParsed + comparParsedB;
                    if(result.Equals(2020))
                    {
                        return itemParsed * comparParsed * comparParsedB;
                    }
                }
            }
        }
    }
    return null;
}

public void ShowResult(string input)
{
    int? result = GetResultNumberOneB(input);

    if(result.HasValue)
    {
        Console.WriteLine(result.Value);
    }
}

ShowResult(input);
// Out:
// 276432018
// 276432018
// 276432018
// 276432018
// 276432018
// 276432018
